# %%
import os

# folder path
dir_path = '.\\fonts'

# list to store files
res = []

# Iterate directory
for path in os.listdir(dir_path):
    # check if current path is a file
    if os.path.isfile(os.path.join(dir_path, path)):
        print(path)
# Out:
# AA-BebasNeue.ttf
# AA-Duke_Fill.otf
# AA-Higherup.ttf
# Academy.ttf
# AcademyCTT_Bold.ttf
# AdLib_Win95BT.ttf
# AdonisC-Bold.ttf
# AdonisC.ttf
# AGAalenBold.ttf
# AGCrownStyle.ttf
# AGCrownStyle_Oblique.ttf
# AGGalleonC.otf
# AGGalleonC_Bold.otf
# Ahellya.ttf
# Albertus_Medium.ttf
# Alfios_Bold.otf
# AmbassadoreType.ttf
# Ambassadore_Type_Shura.ttf
# Andika_Regular.ttf
# Anonymous_Pro.ttf
# Anonymous_Pro_B.ttf
# Antique_Olive.ttf
# Antique_Olive_Bold.ttf
# Aquarion.ttf
# Arimo_Bold.ttf
# Arimo_Bold_Italic.ttf
# Arimo_Italic.ttf
# Arimo_Regular.ttf
# Arion_Bold.ttf
# Arion_Bold_Italic.ttf
# Arion_Normal.ttf
# Arion_Normal_Italic.ttf
# Aroania.otf
# Aroania_Bold.otf
# Arsenal_Bold.otf
# Arsenal_Bold_Italic.otf
# Arsenal_Italic.otf
# Arsenal_Regular.otf
# atthewindowPRO_Regular.ttf
# Autoradiographic_Rg.ttf
# AvantGardeC.otf
# AvantGardeC_Bold.otf
# AvantGardeC_Bold_Italic.otf
# AvantGardeC_Italic.otf
# Avanti.ttf
# Avanti_Bold.ttf
# Avanti_BoldItalic.ttf
# Avanti_Italic.ttf
# Avdira_Bold.otf
# Avdira_Bold_Italic.otf
# Aver.ttf
# Aver_Bold.ttf
# Aver_Bold_Italic.ttf
# Aver_Italic.ttf
# Azbuka01.ttf
# Azbuka02_Italic.ttf
# Azbuka04.ttf
# Azbuka06.ttf
# a_AlbionicExp_Bold.ttf
# a_AlbionicNr_Bold.ttf
# a_AlbionicTitulInfl_Bold.ttf
# a_Albionic_Bold.ttf
# a_Alterna_Regular.ttf
# a_AntiqueTrady.ttf
# a_AntiqueTradyNr.ttf
# a_AvanteNrBook_Regular.ttf
# B20_Sans.ttf
# BalticaC.otf
# BalticaC_Bold.otf
# Baskerville_A.Z_PS.ttf
# Baskerville_A.Z_PS_Bold.ttf
# Baskerville_Win95bt.ttf
# Baskerville_Win95bt_Bold.ttf
# BauhausC_Heavy_Regular.ttf
# BauhausC_Light_Bold.ttf
# BauhausC_Light_Regular.ttf
# BauhausC_Medium_Bold.ttf
# BauhausC_Medium_Regular.ttf
# BDP_GeLLY.ttf
# Bebas_Neue_Cyrillic.ttf
# Bender.otf
# Bender_Black.otf
# Bender_Bold.otf
# Bitter_Bold.otf
# Bitter_Regular.otf
# BlocExtCond.otf
# Blogger_Sans.otf
# Blogger_Sans_Bold.otf
# Blogger_Sans_Light_Regular.otf
# Blogger_Sans_Medium_Regular.otf
# BodoniCondC.ttf
# BodoniCyrillicFWF.ttf
# BodoniCyrillicFWF_Bold.ttf
# BodoniCyrillicFWF_Regular.ttf
# BodoniC_Bold.ttf
# BookmanC.otf
# BookmanC_Bold.otf
# Bookman_Old_Style_Bold.ttf
# Bookman_Old_Style_Italic.ttf
# Bookman_Old_Style_Regular.ttf
# Book_Antiqua.ttf
# Book_Antiqua_Bold.ttf
# CG_Times.ttf
# CG_Times_Bold.ttf
# CG_Times_Bold_Italic.ttf
# CG_Times_Italic.ttf
# Royal_Times_New_Roman.ttf
# Times_CY.ttf
# Times_CY_Bold.ttf
# Times_Ten_LT_Std_Roman_Bold.otf
# Times_Ten_LT_Std_Roman_Bold_Italic.otf
# Times_Ten_LT_Std_Roman_Italic.otf
# Times_Ten_LT_Std_Roman_Regular.otf
