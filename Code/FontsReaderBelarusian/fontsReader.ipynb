# %%
import os

# folder path
dir_path = '.\\Belarusian Fonts'

# list to store files
res = []

# Iterate directory
for path in os.listdir(dir_path):
    # check if current path is a file
    if os.path.isfile(os.path.join(dir_path, path)):
        print(path)
# Out:
# Alice-Regular.ttf
# alpha_echo.ttf
# AMERIKAA.ttf
# AMERIKA_.ttf
# AMERSN__.ttf
# Anonymous_Pro.ttf
# Anonymous_Pro_B.ttf
# Anonymous_Pro_BI.ttf
# Anonymous_Pro_I.ttf
# Arimo-Bold.ttf
# Arimo-BoldItalic.ttf
# Arimo-Italic.ttf
# Arimo-Regular.ttf
# Arsenal-Bold.otf
# Arsenal-BoldItalic.otf
# Arsenal-Italic.otf
# Arsenal-Regular.otf
# azoft-sans-bold-italic.ttf
# azoft-sans-bold.ttf
# azoft-sans-italic.ttf
# azoft-sans.ttf
# Bitter-Bold.otf
# Bitter-BoldItalic.otf
# Bitter-Italic.otf
# Bitter-Regular.otf
# BlackCasper.ttf
# Blogger_Sans-Bold.otf
# Blogger_Sans-Bold_Italic.otf
# Blogger_Sans-Italic.otf
# Blogger_Sans-Light.otf
# Blogger_Sans-Light_Italic.otf
# Blogger_Sans-Medium.otf
# Blogger_Sans-Medium_Italic.otf
# Blogger_Sans.otf
# Capture_it.ttf
# Capture_it_2.ttf
# CaviarDreams.ttf
# CaviarDreams_BoldItalic.ttf
# CaviarDreams_Italic.ttf
# Caviar_Dreams_Bold.ttf
# CharisSILB.ttf
# CharisSILBI.ttf
# CharisSILI.ttf
# CharisSILR.ttf
# ClearSans-Bold.ttf
# ClearSans-BoldItalic.ttf
# ...
